# %% [markdown]
# # Mars Rover Terrain EDA\n\nThis notebook is a starter for inspecting terrain images, label distributions, and data quality checks.

# %%
from pathlib import Path\nimport pandas as pd\n\nraw_dir = Path('../data/raw')\nfiles = list(raw_dir.glob('*')) if raw_dir.exists() else []\npd.DataFrame({'file': [f.name for f in files]}).head()
